# %%
test_all_re_1=[(([0, 5, 6], 0.14362630806863308), {0: 'a feedback control system', 1: ',', 2: 'provided', 3: 'to', 4: 'reduce', 5: 'bearing', 6: 'loads', 7: 'on', 8: 'the bearing', 9: ',', 10: 'comprises', 11: 'a sensor', 12: 'mounted in', 13: 'a bearing housing', 14: 'positioned', 15: 'to', 16: 'measure', 17: 'the distance', 18: 'of', 19: 'a gap', 20: 'between', 21: 'a top end', 22: 'of', 23: 'the shaft', 24: 'and', 25: 'a lower surface', 26: 'of', 27: 'the sensor', 28: '.'}), (([0, 4, 8], 0.05523030832409859), {0: 'a feedback control system', 1: ',', 2: 'provided', 3: 'to', 4: 'reduce', 5: 'bearing', 6: 'loads', 7: 'on', 8: 'the bearing', 9: ',', 10: 'comprises', 11: 'a sensor', 12: 'mounted in', 13: 'a bearing housing', 14: 'positioned', 15: 'to', 16: 'measure', 17: 'the distance', 18: 'of', 19: 'a gap', 20: 'between', 21: 'a top end', 22: 'of', 23: 'the shaft', 24: 'and', 25: 'a lower surface', 26: 'of', 27: 'the sensor', 28: '.'}), (([0, 10, 11], 0.057122115045785904), {0: 'a feedback control system', 1: ',', 2: 'provided', 3: 'to', 4: 'reduce', 5: 'bearing', 6: 'loads', 7: 'on', 8: 'the bearing', 9: ',', 10: 'comprises', 11: 'a sensor', 12: 'mounted in', 13: 'a bearing housing', 14: 'positioned', 15: 'to', 16: 'measure', 17: 'the distance', 18: 'of', 19: 'a gap', 20: 'between', 21: 'a top end', 22: 'of', 23: 'the shaft', 24: 'and', 25: 'a lower surface', 26: 'of', 27: 'the sensor', 28: '.'}), (([0, 4, 13], 0.053493063896894455), {0: 'a feedback control system', 1: ',', 2: 'provided', 3: 'to', 4: 'reduce', 5: 'bearing', 6: 'loads', 7: 'on', 8: 'the bearing', 9: ',', 10: 'comprises', 11: 'a sensor', 12: 'mounted in', 13: 'a bearing housing', 14: 'positioned', 15: 'to', 16: 'measure', 17: 'the distance', 18: 'of', 19: 'a gap', 20: 'between', 21: 'a top end', 22: 'of', 23: 'the shaft', 24: 'and', 25: 'a lower surface', 26: 'of', 27: 'the sensor', 28: '.'}), (([0, 16, 17], 0.05699444189667702), {0: 'a feedback control system', 1: ',', 2: 'provided', 3: 'to', 4: 'reduce', 5: 'bearing', 6: 'loads', 7: 'on', 8: 'the bearing', 9: ',', 10: 'comprises', 11: 'a sensor', 12: 'mounted in', 13: 'a bearing housing', 14: 'positioned', 15: 'to', 16: 'measure', 17: 'the distance', 18: 'of', 19: 'a gap', 20: 'between', 21: 'a top end', 22: 'of', 23: 'the shaft', 24: 'and', 25: 'a lower surface', 26: 'of', 27: 'the sensor', 28: '.'}), (([0, 4, 19], 0.04878399521112442), {0: 'a feedback control system', 1: ',', 2: 'provided', 3: 'to', 4: 'reduce', 5: 'bearing', 6: 'loads', 7: 'on', 8: 'the bearing', 9: ',', 10: 'comprises', 11: 'a sensor', 12: 'mounted in', 13: 'a bearing housing', 14: 'positioned', 15: 'to', 16: 'measure', 17: 'the distance', 18: 'of', 19: 'a gap', 20: 'between', 21: 'a top end', 22: 'of', 23: 'the shaft', 24: 'and', 25: 'a lower surface', 26: 'of', 27: 'the sensor', 28: '.'}), (([0, 4, 21], 0.044417692348361015), {0: 'a feedback control system', 1: ',', 2: 'provided', 3: 'to', 4: 'reduce', 5: 'bearing', 6: 'loads', 7: 'on', 8: 'the bearing', 9: ',', 10: 'comprises', 11: 'a sensor', 12: 'mounted in', 13: 'a bearing housing', 14: 'positioned', 15: 'to', 16: 'measure', 17: 'the distance', 18: 'of', 19: 'a gap', 20: 'between', 21: 'a top end', 22: 'of', 23: 'the shaft', 24: 'and', 25: 'a lower surface', 26: 'of', 27: 'the sensor', 28: '.'}), (([0, 4, 23], 0.045050433836877346), {0: 'a feedback control system', 1: ',', 2: 'provided', 3: 'to', 4: 'reduce', 5: 'bearing', 6: 'loads', 7: 'on', 8: 'the bearing', 9: ',', 10: 'comprises', 11: 'a sensor', 12: 'mounted in', 13: 'a bearing housing', 14: 'positioned', 15: 'to', 16: 'measure', 17: 'the distance', 18: 'of', 19: 'a gap', 20: 'between', 21: 'a top end', 22: 'of', 23: 'the shaft', 24: 'and', 25: 'a lower surface', 26: 'of', 27: 'the sensor', 28: '.'}), (([0, 4, 25], 0.04735935013741255), {0: 'a feedback control system', 1: ',', 2: 'provided', 3: 'to', 4: 'reduce', 5: 'bearing', 6: 'loads', 7: 'on', 8: 'the bearing', 9: ',', 10: 'comprises', 11: 'a sensor', 12: 'mounted in', 13: 'a bearing housing', 14: 'positioned', 15: 'to', 16: 'measure', 17: 'the distance', 18: 'of', 19: 'a gap', 20: 'between', 21: 'a top end', 22: 'of', 23: 'the shaft', 24: 'and', 25: 'a lower surface', 26: 'of', 27: 'the sensor', 28: '.'}), (([0, 4, 27], 0.04657481238245964), {0: 'a feedback control system', 1: ',', 2: 'provided', 3: 'to', 4: 'reduce', 5: 'bearing', 6: 'loads', 7: 'on', 8: 'the bearing', 9: ',', 10: 'comprises', 11: 'a sensor', 12: 'mounted in', 13: 'a bearing housing', 14: 'positioned', 15: 'to', 16: 'measure', 17: 'the distance', 18: 'of', 19: 'a gap', 20: 'between', 21: 'a top end', 22: 'of', 23: 'the shaft', 24: 'and', 25: 'a lower surface', 26: 'of', 27: 'the sensor', 28: '.'}), (([6, 10, 11], 0.060095289722085), {0: 'a feedback control system', 1: ',', 2: 'provided', 3: 'to', 4: 'reduce', 5: 'bearing', 6: 'loads', 7: 'on', 8: 'the bearing', 9: ',', 10: 'comprises', 11: 'a sensor', 12: 'mounted in', 13: 'a bearing housing', 14: 'positioned', 15: 'to', 16: 'measure', 17: 'the distance', 18: 'of', 19: 'a gap', 20: 'between', 21: 'a top end', 22: 'of', 23: 'the shaft', 24: 'and', 25: 'a lower surface', 26: 'of', 27: 'the sensor', 28: '.'}), (([6, 10, 13], 0.045095156878232956), {0: 'a feedback control system', 1: ',', 2: 'provided', 3: 'to', 4: 'reduce', 5: 'bearing', 6: 'loads', 7: 'on', 8: 'the bearing', 9: ',', 10: 'comprises', 11: 'a sensor', 12: 'mounted in', 13: 'a bearing housing', 14: 'positioned', 15: 'to', 16: 'measure', 17: 'the distance', 18: 'of', 19: 'a gap', 20: 'between', 21: 'a top end', 22: 'of', 23: 'the shaft', 24: 'and', 25: 'a lower surface', 26: 'of', 27: 'the sensor', 28: '.'}), (([6, 16, 17], 0.05438375286757946), {0: 'a feedback control system', 1: ',', 2: 'provided', 3: 'to', 4: 'reduce', 5: 'bearing', 6: 'loads', 7: 'on', 8: 'the bearing', 9: ',', 10: 'comprises', 11: 'a sensor', 12: 'mounted in', 13: 'a bearing housing', 14: 'positioned', 15: 'to', 16: 'measure', 17: 'the distance', 18: 'of', 19: 'a gap', 20: 'between', 21: 'a top end', 22: 'of', 23: 'the shaft', 24: 'and', 25: 'a lower surface', 26: 'of', 27: 'the sensor', 28: '.'}), (([6, 14, 19], 0.04191224277019501), {0: 'a feedback control system', 1: ',', 2: 'provided', 3: 'to', 4: 'reduce', 5: 'bearing', 6: 'loads', 7: 'on', 8: 'the bearing', 9: ',', 10: 'comprises', 11: 'a sensor', 12: 'mounted in', 13: 'a bearing housing', 14: 'positioned', 15: 'to', 16: 'measure', 17: 'the distance', 18: 'of', 19: 'a gap', 20: 'between', 21: 'a top end', 22: 'of', 23: 'the shaft', 24: 'and', 25: 'a lower surface', 26: 'of', 27: 'the sensor', 28: '.'}), (([6, 10, 21], 0.03723613265901804), {0: 'a feedback control system', 1: ',', 2: 'provided', 3: 'to', 4: 'reduce', 5: 'bearing', 6: 'loads', 7: 'on', 8: 'the bearing', 9: ',', 10: 'comprises', 11: 'a sensor', 12: 'mounted in', 13: 'a bearing housing', 14: 'positioned', 15: 'to', 16: 'measure', 17: 'the distance', 18: 'of', 19: 'a gap', 20: 'between', 21: 'a top end', 22: 'of', 23: 'the shaft', 24: 'and', 25: 'a lower surface', 26: 'of', 27: 'the sensor', 28: '.'}), (([6, 10, 23], 0.04032389726489782), {0: 'a feedback control system', 1: ',', 2: 'provided', 3: 'to', 4: 'reduce', 5: 'bearing', 6: 'loads', 7: 'on', 8: 'the bearing', 9: ',', 10: 'comprises', 11: 'a sensor', 12: 'mounted in', 13: 'a bearing housing', 14: 'positioned', 15: 'to', 16: 'measure', 17: 'the distance', 18: 'of', 19: 'a gap', 20: 'between', 21: 'a top end', 22: 'of', 23: 'the shaft', 24: 'and', 25: 'a lower surface', 26: 'of', 27: 'the sensor', 28: '.'}), (([6, 10, 25], 0.0383484847843647), {0: 'a feedback control system', 1: ',', 2: 'provided', 3: 'to', 4: 'reduce', 5: 'bearing', 6: 'loads', 7: 'on', 8: 'the bearing', 9: ',', 10: 'comprises', 11: 'a sensor', 12: 'mounted in', 13: 'a bearing housing', 14: 'positioned', 15: 'to', 16: 'measure', 17: 'the distance', 18: 'of', 19: 'a gap', 20: 'between', 21: 'a top end', 22: 'of', 23: 'the shaft', 24: 'and', 25: 'a lower surface', 26: 'of', 27: 'the sensor', 28: '.'}), (([6, 10, 27], 0.03957377281039953), {0: 'a feedback control system', 1: ',', 2: 'provided', 3: 'to', 4: 'reduce', 5: 'bearing', 6: 'loads', 7: 'on', 8: 'the bearing', 9: ',', 10: 'comprises', 11: 'a sensor', 12: 'mounted in', 13: 'a bearing housing', 14: 'positioned', 15: 'to', 16: 'measure', 17: 'the distance', 18: 'of', 19: 'a gap', 20: 'between', 21: 'a top end', 22: 'of', 23: 'the shaft', 24: 'and', 25: 'a lower surface', 26: 'of', 27: 'the sensor', 28: '.'}), (([8, 10, 11], 0.0629549901932478), {0: 'a feedback control system', 1: ',', 2: 'provided', 3: 'to', 4: 'reduce', 5: 'bearing', 6: 'loads', 7: 'on', 8: 'the bearing', 9: ',', 10: 'comprises', 11: 'a sensor', 12: 'mounted in', 13: 'a bearing housing', 14: 'positioned', 15: 'to', 16: 'measure', 17: 'the distance', 18: 'of', 19: 'a gap', 20: 'between', 21: 'a top end', 22: 'of', 23: 'the shaft', 24: 'and', 25: 'a lower surface', 26: 'of', 27: 'the sensor', 28: '.'}), (([8, 10, 13], 0.04795485734939575), {0: 'a feedback control system', 1: ',', 2: 'provided', 3: 'to', 4: 'reduce', 5: 'bearing', 6: 'loads', 7: 'on', 8: 'the bearing', 9: ',', 10: 'comprises', 11: 'a sensor', 12: 'mounted in', 13: 'a bearing housing', 14: 'positioned', 15: 'to', 16: 'measure', 17: 'the distance', 18: 'of', 19: 'a gap', 20: 'between', 21: 'a top end', 22: 'of', 23: 'the shaft', 24: 'and', 25: 'a lower surface', 26: 'of', 27: 'the sensor', 28: '.'}), (([8, 16, 17], 0.054662518203258514), {0: 'a feedback control system', 1: ',', 2: 'provided', 3: 'to', 4: 'reduce', 5: 'bearing', 6: 'loads', 7: 'on', 8: 'the bearing', 9: ',', 10: 'comprises', 11: 'a sensor', 12: 'mounted in', 13: 'a bearing housing', 14: 'positioned', 15: 'to', 16: 'measure', 17: 'the distance', 18: 'of', 19: 'a gap', 20: 'between', 21: 'a top end', 22: 'of', 23: 'the shaft', 24: 'and', 25: 'a lower surface', 26: 'of', 27: 'the sensor', 28: '.'}), (([8, 10, 19], 0.04293336346745491), {0: 'a feedback control system', 1: ',', 2: 'provided', 3: 'to', 4: 'reduce', 5: 'bearing', 6: 'loads', 7: 'on', 8: 'the bearing', 9: ',', 10: 'comprises', 11: 'a sensor', 12: 'mounted in', 13: 'a bearing housing', 14: 'positioned', 15: 'to', 16: 'measure', 17: 'the distance', 18: 'of', 19: 'a gap', 20: 'between', 21: 'a top end', 22: 'of', 23: 'the shaft', 24: 'and', 25: 'a lower surface', 26: 'of', 27: 'the sensor', 28: '.'}), (([8, 10, 21], 0.040095833130180836), {0: 'a feedback control system', 1: ',', 2: 'provided', 3: 'to', 4: 'reduce', 5: 'bearing', 6: 'loads', 7: 'on', 8: 'the bearing', 9: ',', 10: 'comprises', 11: 'a sensor', 12: 'mounted in', 13: 'a bearing housing', 14: 'positioned', 15: 'to', 16: 'measure', 17: 'the distance', 18: 'of', 19: 'a gap', 20: 'between', 21: 'a top end', 22: 'of', 23: 'the shaft', 24: 'and', 25: 'a lower surface', 26: 'of', 27: 'the sensor', 28: '.'}), (([8, 10, 23], 0.04318359773606062), {0: 'a feedback control system', 1: ',', 2: 'provided', 3: 'to', 4: 'reduce', 5: 'bearing', 6: 'loads', 7: 'on', 8: 'the bearing', 9: ',', 10: 'comprises', 11: 'a sensor', 12: 'mounted in', 13: 'a bearing housing', 14: 'positioned', 15: 'to', 16: 'measure', 17: 'the distance', 18: 'of', 19: 'a gap', 20: 'between', 21: 'a top end', 22: 'of', 23: 'the shaft', 24: 'and', 25: 'a lower surface', 26: 'of', 27: 'the sensor', 28: '.'}), (([8, 10, 25], 0.041208185255527496), {0: 'a feedback control system', 1: ',', 2: 'provided', 3: 'to', 4: 'reduce', 5: 'bearing', 6: 'loads', 7: 'on', 8: 'the bearing', 9: ',', 10: 'comprises', 11: 'a sensor', 12: 'mounted in', 13: 'a bearing housing', 14: 'positioned', 15: 'to', 16: 'measure', 17: 'the distance', 18: 'of', 19: 'a gap', 20: 'between', 21: 'a top end', 22: 'of', 23: 'the shaft', 24: 'and', 25: 'a lower surface', 26: 'of', 27: 'the sensor', 28: '.'}), (([8, 10, 27], 0.04243347328156233), {0: 'a feedback control system', 1: ',', 2: 'provided', 3: 'to', 4: 'reduce', 5: 'bearing', 6: 'loads', 7: 'on', 8: 'the bearing', 9: ',', 10: 'comprises', 11: 'a sensor', 12: 'mounted in', 13: 'a bearing housing', 14: 'positioned', 15: 'to', 16: 'measure', 17: 'the distance', 18: 'of', 19: 'a gap', 20: 'between', 21: 'a top end', 22: 'of', 23: 'the shaft', 24: 'and', 25: 'a lower surface', 26: 'of', 27: 'the sensor', 28: '.'}), (([11, 12, 13], 0.05259258672595024), {0: 'a feedback control system', 1: ',', 2: 'provided', 3: 'to', 4: 'reduce', 5: 'bearing', 6: 'loads', 7: 'on', 8: 'the bearing', 9: ',', 10: 'comprises', 11: 'a sensor', 12: 'mounted in', 13: 'a bearing housing', 14: 'positioned', 15: 'to', 16: 'measure', 17: 'the distance', 18: 'of', 19: 'a gap', 20: 'between', 21: 'a top end', 22: 'of', 23: 'the shaft', 24: 'and', 25: 'a lower surface', 26: 'of', 27: 'the sensor', 28: '.'}), (([11, 16, 17], 0.05551338754594326), {0: 'a feedback control system', 1: ',', 2: 'provided', 3: 'to', 4: 'reduce', 5: 'bearing', 6: 'loads', 7: 'on', 8: 'the bearing', 9: ',', 10: 'comprises', 11: 'a sensor', 12: 'mounted in', 13: 'a bearing housing', 14: 'positioned', 15: 'to', 16: 'measure', 17: 'the distance', 18: 'of', 19: 'a gap', 20: 'between', 21: 'a top end', 22: 'of', 23: 'the shaft', 24: 'and', 25: 'a lower surface', 26: 'of', 27: 'the sensor', 28: '.'}), (([11, 14, 19], 0.04442876577377319), {0: 'a feedback control system', 1: ',', 2: 'provided', 3: 'to', 4: 'reduce', 5: 'bearing', 6: 'loads', 7: 'on', 8: 'the bearing', 9: ',', 10: 'comprises', 11: 'a sensor', 12: 'mounted in', 13: 'a bearing housing', 14: 'positioned', 15: 'to', 16: 'measure', 17: 'the distance', 18: 'of', 19: 'a gap', 20: 'between', 21: 'a top end', 22: 'of', 23: 'the shaft', 24: 'and', 25: 'a lower surface', 26: 'of', 27: 'the sensor', 28: '.'}), (([11, 12, 21], 0.039385066367685795), {0: 'a feedback control system', 1: ',', 2: 'provided', 3: 'to', 4: 'reduce', 5: 'bearing', 6: 'loads', 7: 'on', 8: 'the bearing', 9: ',', 10: 'comprises', 11: 'a sensor', 12: 'mounted in', 13: 'a bearing housing', 14: 'positioned', 15: 'to', 16: 'measure', 17: 'the distance', 18: 'of', 19: 'a gap', 20: 'between', 21: 'a top end', 22: 'of', 23: 'the shaft', 24: 'and', 25: 'a lower surface', 26: 'of', 27: 'the sensor', 28: '.'}), (([11, 12, 23], 0.041865479201078415), {0: 'a feedback control system', 1: ',', 2: 'provided', 3: 'to', 4: 'reduce', 5: 'bearing', 6: 'loads', 7: 'on', 8: 'the bearing', 9: ',', 10: 'comprises', 11: 'a sensor', 12: 'mounted in', 13: 'a bearing housing', 14: 'positioned', 15: 'to', 16: 'measure', 17: 'the distance', 18: 'of', 19: 'a gap', 20: 'between', 21: 'a top end', 22: 'of', 23: 'the shaft', 24: 'and', 25: 'a lower surface', 26: 'of', 27: 'the sensor', 28: '.'}), (([11, 14, 25], 0.03827801439911127), {0: 'a feedback control system', 1: ',', 2: 'provided', 3: 'to', 4: 'reduce', 5: 'bearing', 6: 'loads', 7: 'on', 8: 'the bearing', 9: ',', 10: 'comprises', 11: 'a sensor', 12: 'mounted in', 13: 'a bearing housing', 14: 'positioned', 15: 'to', 16: 'measure', 17: 'the distance', 18: 'of', 19: 'a gap', 20: 'between', 21: 'a top end', 22: 'of', 23: 'the shaft', 24: 'and', 25: 'a lower surface', 26: 'of', 27: 'the sensor', 28: '.'}), (([11, 14, 27], 0.04197405278682709), {0: 'a feedback control system', 1: ',', 2: 'provided', 3: 'to', 4: 'reduce', 5: 'bearing', 6: 'loads', 7: 'on', 8: 'the bearing', 9: ',', 10: 'comprises', 11: 'a sensor', 12: 'mounted in', 13: 'a bearing housing', 14: 'positioned', 15: 'to', 16: 'measure', 17: 'the distance', 18: 'of', 19: 'a gap', 20: 'between', 21: 'a top end', 22: 'of', 23: 'the shaft', 24: 'and', 25: 'a lower surface', 26: 'of', 27: 'the sensor', 28: '.'}), (([13, 16, 17], 0.06570327468216419), {0: 'a feedback control system', 1: ',', 2: 'provided', 3: 'to', 4: 'reduce', 5: 'bearing', 6: 'loads', 7: 'on', 8: 'the bearing', 9: ',', 10: 'comprises', 11: 'a sensor', 12: 'mounted in', 13: 'a bearing housing', 14: 'positioned', 15: 'to', 16: 'measure', 17: 'the distance', 18: 'of', 19: 'a gap', 20: 'between', 21: 'a top end', 22: 'of', 23: 'the shaft', 24: 'and', 25: 'a lower surface', 26: 'of', 27: 'the sensor', 28: '.'}), (([13, 14, 19], 0.0553881898522377), {0: 'a feedback control system', 1: ',', 2: 'provided', 3: 'to', 4: 'reduce', 5: 'bearing', 6: 'loads', 7: 'on', 8: 'the bearing', 9: ',', 10: 'comprises', 11: 'a sensor', 12: 'mounted in', 13: 'a bearing housing', 14: 'positioned', 15: 'to', 16: 'measure', 17: 'the distance', 18: 'of', 19: 'a gap', 20: 'between', 21: 'a top end', 22: 'of', 23: 'the shaft', 24: 'and', 25: 'a lower surface', 26: 'of', 27: 'the sensor', 28: '.'}), (([13, 14, 21], 0.04982979688793421), {0: 'a feedback control system', 1: ',', 2: 'provided', 3: 'to', 4: 'reduce', 5: 'bearing', 6: 'loads', 7: 'on', 8: 'the bearing', 9: ',', 10: 'comprises', 11: 'a sensor', 12: 'mounted in', 13: 'a bearing housing', 14: 'positioned', 15: 'to', 16: 'measure', 17: 'the distance', 18: 'of', 19: 'a gap', 20: 'between', 21: 'a top end', 22: 'of', 23: 'the shaft', 24: 'and', 25: 'a lower surface', 26: 'of', 27: 'the sensor', 28: '.'}), (([13, 14, 23], 0.052118491381406784), {0: 'a feedback control system', 1: ',', 2: 'provided', 3: 'to', 4: 'reduce', 5: 'bearing', 6: 'loads', 7: 'on', 8: 'the bearing', 9: ',', 10: 'comprises', 11: 'a sensor', 12: 'mounted in', 13: 'a bearing housing', 14: 'positioned', 15: 'to', 16: 'measure', 17: 'the distance', 18: 'of', 19: 'a gap', 20: 'between', 21: 'a top end', 22: 'of', 23: 'the shaft', 24: 'and', 25: 'a lower surface', 26: 'of', 27: 'the sensor', 28: '.'}), (([13, 14, 25], 0.04923743847757578), {0: 'a feedback control system', 1: ',', 2: 'provided', 3: 'to', 4: 'reduce', 5: 'bearing', 6: 'loads', 7: 'on', 8: 'the bearing', 9: ',', 10: 'comprises', 11: 'a sensor', 12: 'mounted in', 13: 'a bearing housing', 14: 'positioned', 15: 'to', 16: 'measure', 17: 'the distance', 18: 'of', 19: 'a gap', 20: 'between', 21: 'a top end', 22: 'of', 23: 'the shaft', 24: 'and', 25: 'a lower surface', 26: 'of', 27: 'the sensor', 28: '.'}), (([13, 14, 27], 0.052933476865291595), {0: 'a feedback control system', 1: ',', 2: 'provided', 3: 'to', 4: 'reduce', 5: 'bearing', 6: 'loads', 7: 'on', 8: 'the bearing', 9: ',', 10: 'comprises', 11: 'a sensor', 12: 'mounted in', 13: 'a bearing housing', 14: 'positioned', 15: 'to', 16: 'measure', 17: 'the distance', 18: 'of', 19: 'a gap', 20: 'between', 21: 'a top end', 22: 'of', 23: 'the shaft', 24: 'and', 25: 'a lower surface', 26: 'of', 27: 'the sensor', 28: '.'})]
test_all_re_2=[(([0, 6, 7], 0.12901905551552773), {0: 'response', 1: 'to', 2: 'changes', 3: 'in', 4: 'the distance', 5: 'the sensor', 6: 'sends', 7: 'an electrical signal', 8: 'to', 9: 'a controller', 10: 'which', 11: 'in', 12: 'turn', 13: 'provides', 14: 'variable electric current', 15: 'to', 16: 'the magnetic off-loader', 17: 'which', 18: 'then', 19: 'provides', 20: 'a magnetic lifting force', 21: 'to', 22: 'the rotor', 23: 'on', 24: 'the shaft', 25: 'to', 26: 'minimize', 27: 'bearing load', 28: '.'}), (([0, 6, 9], 0.09830215200781822), {0: 'response', 1: 'to', 2: 'changes', 3: 'in', 4: 'the distance', 5: 'the sensor', 6: 'sends', 7: 'an electrical signal', 8: 'to', 9: 'a controller', 10: 'which', 11: 'in', 12: 'turn', 13: 'provides', 14: 'variable electric current', 15: 'to', 16: 'the magnetic off-loader', 17: 'which', 18: 'then', 19: 'provides', 20: 'a magnetic lifting force', 21: 'to', 22: 'the rotor', 23: 'on', 24: 'the shaft', 25: 'to', 26: 'minimize', 27: 'bearing load', 28: '.'}), (([0, 6, 12], 0.09268828481435776), {0: 'response', 1: 'to', 2: 'changes', 3: 'in', 4: 'the distance', 5: 'the sensor', 6: 'sends', 7: 'an electrical signal', 8: 'to', 9: 'a controller', 10: 'which', 11: 'in', 12: 'turn', 13: 'provides', 14: 'variable electric current', 15: 'to', 16: 'the magnetic off-loader', 17: 'which', 18: 'then', 19: 'provides', 20: 'a magnetic lifting force', 21: 'to', 22: 'the rotor', 23: 'on', 24: 'the shaft', 25: 'to', 26: 'minimize', 27: 'bearing load', 28: '.'}), (([0, 6, 14], 0.09795243293046951), {0: 'response', 1: 'to', 2: 'changes', 3: 'in', 4: 'the distance', 5: 'the sensor', 6: 'sends', 7: 'an electrical signal', 8: 'to', 9: 'a controller', 10: 'which', 11: 'in', 12: 'turn', 13: 'provides', 14: 'variable electric current', 15: 'to', 16: 'the magnetic off-loader', 17: 'which', 18: 'then', 19: 'provides', 20: 'a magnetic lifting force', 21: 'to', 22: 'the rotor', 23: 'on', 24: 'the shaft', 25: 'to', 26: 'minimize', 27: 'bearing load', 28: '.'}), (([0, 6, 16], 0.0884134704247117), {0: 'response', 1: 'to', 2: 'changes', 3: 'in', 4: 'the distance', 5: 'the sensor', 6: 'sends', 7: 'an electrical signal', 8: 'to', 9: 'a controller', 10: 'which', 11: 'in', 12: 'turn', 13: 'provides', 14: 'variable electric current', 15: 'to', 16: 'the magnetic off-loader', 17: 'which', 18: 'then', 19: 'provides', 20: 'a magnetic lifting force', 21: 'to', 22: 'the rotor', 23: 'on', 24: 'the shaft', 25: 'to', 26: 'minimize', 27: 'bearing load', 28: '.'}), (([0, 6, 20], 0.08962442446500063), {0: 'response', 1: 'to', 2: 'changes', 3: 'in', 4: 'the distance', 5: 'the sensor', 6: 'sends', 7: 'an electrical signal', 8: 'to', 9: 'a controller', 10: 'which', 11: 'in', 12: 'turn', 13: 'provides', 14: 'variable electric current', 15: 'to', 16: 'the magnetic off-loader', 17: 'which', 18: 'then', 19: 'provides', 20: 'a magnetic lifting force', 21: 'to', 22: 'the rotor', 23: 'on', 24: 'the shaft', 25: 'to', 26: 'minimize', 27: 'bearing load', 28: '.'}), (([0, 6, 22], 0.08815069403499365), {0: 'response', 1: 'to', 2: 'changes', 3: 'in', 4: 'the distance', 5: 'the sensor', 6: 'sends', 7: 'an electrical signal', 8: 'to', 9: 'a controller', 10: 'which', 11: 'in', 12: 'turn', 13: 'provides', 14: 'variable electric current', 15: 'to', 16: 'the magnetic off-loader', 17: 'which', 18: 'then', 19: 'provides', 20: 'a magnetic lifting force', 21: 'to', 22: 'the rotor', 23: 'on', 24: 'the shaft', 25: 'to', 26: 'minimize', 27: 'bearing load', 28: '.'}), (([0, 6, 24], 0.08610594552010298), {0: 'response', 1: 'to', 2: 'changes', 3: 'in', 4: 'the distance', 5: 'the sensor', 6: 'sends', 7: 'an electrical signal', 8: 'to', 9: 'a controller', 10: 'which', 11: 'in', 12: 'turn', 13: 'provides', 14: 'variable electric current', 15: 'to', 16: 'the magnetic off-loader', 17: 'which', 18: 'then', 19: 'provides', 20: 'a magnetic lifting force', 21: 'to', 22: 'the rotor', 23: 'on', 24: 'the shaft', 25: 'to', 26: 'minimize', 27: 'bearing load', 28: '.'}), (([0, 6, 27], 0.09110627602785826), {0: 'response', 1: 'to', 2: 'changes', 3: 'in', 4: 'the distance', 5: 'the sensor', 6: 'sends', 7: 'an electrical signal', 8: 'to', 9: 'a controller', 10: 'which', 11: 'in', 12: 'turn', 13: 'provides', 14: 'variable electric current', 15: 'to', 16: 'the magnetic off-loader', 17: 'which', 18: 'then', 19: 'provides', 20: 'a magnetic lifting force', 21: 'to', 22: 'the rotor', 23: 'on', 24: 'the shaft', 25: 'to', 26: 'minimize', 27: 'bearing load', 28: '.'}), (([2, 6, 7], 0.09303561225533485), {0: 'response', 1: 'to', 2: 'changes', 3: 'in', 4: 'the distance', 5: 'the sensor', 6: 'sends', 7: 'an electrical signal', 8: 'to', 9: 'a controller', 10: 'which', 11: 'in', 12: 'turn', 13: 'provides', 14: 'variable electric current', 15: 'to', 16: 'the magnetic off-loader', 17: 'which', 18: 'then', 19: 'provides', 20: 'a magnetic lifting force', 21: 'to', 22: 'the rotor', 23: 'on', 24: 'the shaft', 25: 'to', 26: 'minimize', 27: 'bearing load', 28: '.'}), (([2, 6, 9], 0.06231870874762535), {0: 'response', 1: 'to', 2: 'changes', 3: 'in', 4: 'the distance', 5: 'the sensor', 6: 'sends', 7: 'an electrical signal', 8: 'to', 9: 'a controller', 10: 'which', 11: 'in', 12: 'turn', 13: 'provides', 14: 'variable electric current', 15: 'to', 16: 'the magnetic off-loader', 17: 'which', 18: 'then', 19: 'provides', 20: 'a magnetic lifting force', 21: 'to', 22: 'the rotor', 23: 'on', 24: 'the shaft', 25: 'to', 26: 'minimize', 27: 'bearing load', 28: '.'}), (([2, 6, 12], 0.056704841554164886), {0: 'response', 1: 'to', 2: 'changes', 3: 'in', 4: 'the distance', 5: 'the sensor', 6: 'sends', 7: 'an electrical signal', 8: 'to', 9: 'a controller', 10: 'which', 11: 'in', 12: 'turn', 13: 'provides', 14: 'variable electric current', 15: 'to', 16: 'the magnetic off-loader', 17: 'which', 18: 'then', 19: 'provides', 20: 'a magnetic lifting force', 21: 'to', 22: 'the rotor', 23: 'on', 24: 'the shaft', 25: 'to', 26: 'minimize', 27: 'bearing load', 28: '.'}), (([2, 6, 14], 0.06196898967027664), {0: 'response', 1: 'to', 2: 'changes', 3: 'in', 4: 'the distance', 5: 'the sensor', 6: 'sends', 7: 'an electrical signal', 8: 'to', 9: 'a controller', 10: 'which', 11: 'in', 12: 'turn', 13: 'provides', 14: 'variable electric current', 15: 'to', 16: 'the magnetic off-loader', 17: 'which', 18: 'then', 19: 'provides', 20: 'a magnetic lifting force', 21: 'to', 22: 'the rotor', 23: 'on', 24: 'the shaft', 25: 'to', 26: 'minimize', 27: 'bearing load', 28: '.'}), (([2, 6, 16], 0.05243002716451883), {0: 'response', 1: 'to', 2: 'changes', 3: 'in', 4: 'the distance', 5: 'the sensor', 6: 'sends', 7: 'an electrical signal', 8: 'to', 9: 'a controller', 10: 'which', 11: 'in', 12: 'turn', 13: 'provides', 14: 'variable electric current', 15: 'to', 16: 'the magnetic off-loader', 17: 'which', 18: 'then', 19: 'provides', 20: 'a magnetic lifting force', 21: 'to', 22: 'the rotor', 23: 'on', 24: 'the shaft', 25: 'to', 26: 'minimize', 27: 'bearing load', 28: '.'}), (([2, 6, 20], 0.05364098120480776), {0: 'response', 1: 'to', 2: 'changes', 3: 'in', 4: 'the distance', 5: 'the sensor', 6: 'sends', 7: 'an electrical signal', 8: 'to', 9: 'a controller', 10: 'which', 11: 'in', 12: 'turn', 13: 'provides', 14: 'variable electric current', 15: 'to', 16: 'the magnetic off-loader', 17: 'which', 18: 'then', 19: 'provides', 20: 'a magnetic lifting force', 21: 'to', 22: 'the rotor', 23: 'on', 24: 'the shaft', 25: 'to', 26: 'minimize', 27: 'bearing load', 28: '.'}), (([2, 6, 22], 0.05216725077480078), {0: 'response', 1: 'to', 2: 'changes', 3: 'in', 4: 'the distance', 5: 'the sensor', 6: 'sends', 7: 'an electrical signal', 8: 'to', 9: 'a controller', 10: 'which', 11: 'in', 12: 'turn', 13: 'provides', 14: 'variable electric current', 15: 'to', 16: 'the magnetic off-loader', 17: 'which', 18: 'then', 19: 'provides', 20: 'a magnetic lifting force', 21: 'to', 22: 'the rotor', 23: 'on', 24: 'the shaft', 25: 'to', 26: 'minimize', 27: 'bearing load', 28: '.'}), (([2, 6, 24], 0.05012250225991011), {0: 'response', 1: 'to', 2: 'changes', 3: 'in', 4: 'the distance', 5: 'the sensor', 6: 'sends', 7: 'an electrical signal', 8: 'to', 9: 'a controller', 10: 'which', 11: 'in', 12: 'turn', 13: 'provides', 14: 'variable electric current', 15: 'to', 16: 'the magnetic off-loader', 17: 'which', 18: 'then', 19: 'provides', 20: 'a magnetic lifting force', 21: 'to', 22: 'the rotor', 23: 'on', 24: 'the shaft', 25: 'to', 26: 'minimize', 27: 'bearing load', 28: '.'}), (([2, 26, 27], 0.06922488659620285), {0: 'response', 1: 'to', 2: 'changes', 3: 'in', 4: 'the distance', 5: 'the sensor', 6: 'sends', 7: 'an electrical signal', 8: 'to', 9: 'a controller', 10: 'which', 11: 'in', 12: 'turn', 13: 'provides', 14: 'variable electric current', 15: 'to', 16: 'the magnetic off-loader', 17: 'which', 18: 'then', 19: 'provides', 20: 'a magnetic lifting force', 21: 'to', 22: 'the rotor', 23: 'on', 24: 'the shaft', 25: 'to', 26: 'minimize', 27: 'bearing load', 28: '.'}), (([4, 6, 7], 0.09310507401823997), {0: 'response', 1: 'to', 2: 'changes', 3: 'in', 4: 'the distance', 5: 'the sensor', 6: 'sends', 7: 'an electrical signal', 8: 'to', 9: 'a controller', 10: 'which', 11: 'in', 12: 'turn', 13: 'provides', 14: 'variable electric current', 15: 'to', 16: 'the magnetic off-loader', 17: 'which', 18: 'then', 19: 'provides', 20: 'a magnetic lifting force', 21: 'to', 22: 'the rotor', 23: 'on', 24: 'the shaft', 25: 'to', 26: 'minimize', 27: 'bearing load', 28: '.'}), (([4, 6, 9], 0.06238817051053047), {0: 'response', 1: 'to', 2: 'changes', 3: 'in', 4: 'the distance', 5: 'the sensor', 6: 'sends', 7: 'an electrical signal', 8: 'to', 9: 'a controller', 10: 'which', 11: 'in', 12: 'turn', 13: 'provides', 14: 'variable electric current', 15: 'to', 16: 'the magnetic off-loader', 17: 'which', 18: 'then', 19: 'provides', 20: 'a magnetic lifting force', 21: 'to', 22: 'the rotor', 23: 'on', 24: 'the shaft', 25: 'to', 26: 'minimize', 27: 'bearing load', 28: '.'}), (([4, 6, 12], 0.05677430331707001), {0: 'response', 1: 'to', 2: 'changes', 3: 'in', 4: 'the distance', 5: 'the sensor', 6: 'sends', 7: 'an electrical signal', 8: 'to', 9: 'a controller', 10: 'which', 11: 'in', 12: 'turn', 13: 'provides', 14: 'variable electric current', 15: 'to', 16: 'the magnetic off-loader', 17: 'which', 18: 'then', 19: 'provides', 20: 'a magnetic lifting force', 21: 'to', 22: 'the rotor', 23: 'on', 24: 'the shaft', 25: 'to', 26: 'minimize', 27: 'bearing load', 28: '.'}), (([4, 6, 14], 0.06203845143318176), {0: 'response', 1: 'to', 2: 'changes', 3: 'in', 4: 'the distance', 5: 'the sensor', 6: 'sends', 7: 'an electrical signal', 8: 'to', 9: 'a controller', 10: 'which', 11: 'in', 12: 'turn', 13: 'provides', 14: 'variable electric current', 15: 'to', 16: 'the magnetic off-loader', 17: 'which', 18: 'then', 19: 'provides', 20: 'a magnetic lifting force', 21: 'to', 22: 'the rotor', 23: 'on', 24: 'the shaft', 25: 'to', 26: 'minimize', 27: 'bearing load', 28: '.'}), (([4, 6, 16], 0.052499488927423954), {0: 'response', 1: 'to', 2: 'changes', 3: 'in', 4: 'the distance', 5: 'the sensor', 6: 'sends', 7: 'an electrical signal', 8: 'to', 9: 'a controller', 10: 'which', 11: 'in', 12: 'turn', 13: 'provides', 14: 'variable electric current', 15: 'to', 16: 'the magnetic off-loader', 17: 'which', 18: 'then', 19: 'provides', 20: 'a magnetic lifting force', 21: 'to', 22: 'the rotor', 23: 'on', 24: 'the shaft', 25: 'to', 26: 'minimize', 27: 'bearing load', 28: '.'}), (([4, 6, 20], 0.05371044296771288), {0: 'response', 1: 'to', 2: 'changes', 3: 'in', 4: 'the distance', 5: 'the sensor', 6: 'sends', 7: 'an electrical signal', 8: 'to', 9: 'a controller', 10: 'which', 11: 'in', 12: 'turn', 13: 'provides', 14: 'variable electric current', 15: 'to', 16: 'the magnetic off-loader', 17: 'which', 18: 'then', 19: 'provides', 20: 'a magnetic lifting force', 21: 'to', 22: 'the rotor', 23: 'on', 24: 'the shaft', 25: 'to', 26: 'minimize', 27: 'bearing load', 28: '.'}), (([4, 6, 22], 0.0522367125377059), {0: 'response', 1: 'to', 2: 'changes', 3: 'in', 4: 'the distance', 5: 'the sensor', 6: 'sends', 7: 'an electrical signal', 8: 'to', 9: 'a controller', 10: 'which', 11: 'in', 12: 'turn', 13: 'provides', 14: 'variable electric current', 15: 'to', 16: 'the magnetic off-loader', 17: 'which', 18: 'then', 19: 'provides', 20: 'a magnetic lifting force', 21: 'to', 22: 'the rotor', 23: 'on', 24: 'the shaft', 25: 'to', 26: 'minimize', 27: 'bearing load', 28: '.'}), (([4, 6, 24], 0.05019196402281523), {0: 'response', 1: 'to', 2: 'changes', 3: 'in', 4: 'the distance', 5: 'the sensor', 6: 'sends', 7: 'an electrical signal', 8: 'to', 9: 'a controller', 10: 'which', 11: 'in', 12: 'turn', 13: 'provides', 14: 'variable electric current', 15: 'to', 16: 'the magnetic off-loader', 17: 'which', 18: 'then', 19: 'provides', 20: 'a magnetic lifting force', 21: 'to', 22: 'the rotor', 23: 'on', 24: 'the shaft', 25: 'to', 26: 'minimize', 27: 'bearing load', 28: '.'}), (([4, 26, 27], 0.056505187414586544), {0: 'response', 1: 'to', 2: 'changes', 3: 'in', 4: 'the distance', 5: 'the sensor', 6: 'sends', 7: 'an electrical signal', 8: 'to', 9: 'a controller', 10: 'which', 11: 'in', 12: 'turn', 13: 'provides', 14: 'variable electric current', 15: 'to', 16: 'the magnetic off-loader', 17: 'which', 18: 'then', 19: 'provides', 20: 'a magnetic lifting force', 21: 'to', 22: 'the rotor', 23: 'on', 24: 'the shaft', 25: 'to', 26: 'minimize', 27: 'bearing load', 28: '.'}), (([5, 6, 7], 0.08750765398144722), {0: 'response', 1: 'to', 2: 'changes', 3: 'in', 4: 'the distance', 5: 'the sensor', 6: 'sends', 7: 'an electrical signal', 8: 'to', 9: 'a controller', 10: 'which', 11: 'in', 12: 'turn', 13: 'provides', 14: 'variable electric current', 15: 'to', 16: 'the magnetic off-loader', 17: 'which', 18: 'then', 19: 'provides', 20: 'a magnetic lifting force', 21: 'to', 22: 'the rotor', 23: 'on', 24: 'the shaft', 25: 'to', 26: 'minimize', 27: 'bearing load', 28: '.'}), (([5, 6, 9], 0.05679075047373772), {0: 'response', 1: 'to', 2: 'changes', 3: 'in', 4: 'the distance', 5: 'the sensor', 6: 'sends', 7: 'an electrical signal', 8: 'to', 9: 'a controller', 10: 'which', 11: 'in', 12: 'turn', 13: 'provides', 14: 'variable electric current', 15: 'to', 16: 'the magnetic off-loader', 17: 'which', 18: 'then', 19: 'provides', 20: 'a magnetic lifting force', 21: 'to', 22: 'the rotor', 23: 'on', 24: 'the shaft', 25: 'to', 26: 'minimize', 27: 'bearing load', 28: '.'}), (([5, 6, 12], 0.05117688328027725), {0: 'response', 1: 'to', 2: 'changes', 3: 'in', 4: 'the distance', 5: 'the sensor', 6: 'sends', 7: 'an electrical signal', 8: 'to', 9: 'a controller', 10: 'which', 11: 'in', 12: 'turn', 13: 'provides', 14: 'variable electric current', 15: 'to', 16: 'the magnetic off-loader', 17: 'which', 18: 'then', 19: 'provides', 20: 'a magnetic lifting force', 21: 'to', 22: 'the rotor', 23: 'on', 24: 'the shaft', 25: 'to', 26: 'minimize', 27: 'bearing load', 28: '.'}), (([5, 13, 14], 0.05786504969000816), {0: 'response', 1: 'to', 2: 'changes', 3: 'in', 4: 'the distance', 5: 'the sensor', 6: 'sends', 7: 'an electrical signal', 8: 'to', 9: 'a controller', 10: 'which', 11: 'in', 12: 'turn', 13: 'provides', 14: 'variable electric current', 15: 'to', 16: 'the magnetic off-loader', 17: 'which', 18: 'then', 19: 'provides', 20: 'a magnetic lifting force', 21: 'to', 22: 'the rotor', 23: 'on', 24: 'the shaft', 25: 'to', 26: 'minimize', 27: 'bearing load', 28: '.'}), (([5, 6, 16], 0.0469020688906312), {0: 'response', 1: 'to', 2: 'changes', 3: 'in', 4: 'the distance', 5: 'the sensor', 6: 'sends', 7: 'an electrical signal', 8: 'to', 9: 'a controller', 10: 'which', 11: 'in', 12: 'turn', 13: 'provides', 14: 'variable electric current', 15: 'to', 16: 'the magnetic off-loader', 17: 'which', 18: 'then', 19: 'provides', 20: 'a magnetic lifting force', 21: 'to', 22: 'the rotor', 23: 'on', 24: 'the shaft', 25: 'to', 26: 'minimize', 27: 'bearing load', 28: '.'}), (([5, 6, 20], 0.048113022930920124), {0: 'response', 1: 'to', 2: 'changes', 3: 'in', 4: 'the distance', 5: 'the sensor', 6: 'sends', 7: 'an electrical signal', 8: 'to', 9: 'a controller', 10: 'which', 11: 'in', 12: 'turn', 13: 'provides', 14: 'variable electric current', 15: 'to', 16: 'the magnetic off-loader', 17: 'which', 18: 'then', 19: 'provides', 20: 'a magnetic lifting force', 21: 'to', 22: 'the rotor', 23: 'on', 24: 'the shaft', 25: 'to', 26: 'minimize', 27: 'bearing load', 28: '.'}), (([5, 6, 22], 0.04663929250091314), {0: 'response', 1: 'to', 2: 'changes', 3: 'in', 4: 'the distance', 5: 'the sensor', 6: 'sends', 7: 'an electrical signal', 8: 'to', 9: 'a controller', 10: 'which', 11: 'in', 12: 'turn', 13: 'provides', 14: 'variable electric current', 15: 'to', 16: 'the magnetic off-loader', 17: 'which', 18: 'then', 19: 'provides', 20: 'a magnetic lifting force', 21: 'to', 22: 'the rotor', 23: 'on', 24: 'the shaft', 25: 'to', 26: 'minimize', 27: 'bearing load', 28: '.'}), (([5, 6, 24], 0.04459454398602247), {0: 'response', 1: 'to', 2: 'changes', 3: 'in', 4: 'the distance', 5: 'the sensor', 6: 'sends', 7: 'an electrical signal', 8: 'to', 9: 'a controller', 10: 'which', 11: 'in', 12: 'turn', 13: 'provides', 14: 'variable electric current', 15: 'to', 16: 'the magnetic off-loader', 17: 'which', 18: 'then', 19: 'provides', 20: 'a magnetic lifting force', 21: 'to', 22: 'the rotor', 23: 'on', 24: 'the shaft', 25: 'to', 26: 'minimize', 27: 'bearing load', 28: '.'}), (([5, 26, 27], 0.053700609132647514), {0: 'response', 1: 'to', 2: 'changes', 3: 'in', 4: 'the distance', 5: 'the sensor', 6: 'sends', 7: 'an electrical signal', 8: 'to', 9: 'a controller', 10: 'which', 11: 'in', 12: 'turn', 13: 'provides', 14: 'variable electric current', 15: 'to', 16: 'the magnetic off-loader', 17: 'which', 18: 'then', 19: 'provides', 20: 'a magnetic lifting force', 21: 'to', 22: 'the rotor', 23: 'on', 24: 'the shaft', 25: 'to', 26: 'minimize', 27: 'bearing load', 28: '.'}), (([7, 13, 14], 0.05802134983241558), {0: 'response', 1: 'to', 2: 'changes', 3: 'in', 4: 'the distance', 5: 'the sensor', 6: 'sends', 7: 'an electrical signal', 8: 'to', 9: 'a controller', 10: 'which', 11: 'in', 12: 'turn', 13: 'provides', 14: 'variable electric current', 15: 'to', 16: 'the magnetic off-loader', 17: 'which', 18: 'then', 19: 'provides', 20: 'a magnetic lifting force', 21: 'to', 22: 'the rotor', 23: 'on', 24: 'the shaft', 25: 'to', 26: 'minimize', 27: 'bearing load', 28: '.'}), (([7, 13, 16], 0.03146846313029528), {0: 'response', 1: 'to', 2: 'changes', 3: 'in', 4: 'the distance', 5: 'the sensor', 6: 'sends', 7: 'an electrical signal', 8: 'to', 9: 'a controller', 10: 'which', 11: 'in', 12: 'turn', 13: 'provides', 14: 'variable electric current', 15: 'to', 16: 'the magnetic off-loader', 17: 'which', 18: 'then', 19: 'provides', 20: 'a magnetic lifting force', 21: 'to', 22: 'the rotor', 23: 'on', 24: 'the shaft', 25: 'to', 26: 'minimize', 27: 'bearing load', 28: '.'}), (([7, 19, 20], 0.0383051922544837), {0: 'response', 1: 'to', 2: 'changes', 3: 'in', 4: 'the distance', 5: 'the sensor', 6: 'sends', 7: 'an electrical signal', 8: 'to', 9: 'a controller', 10: 'which', 11: 'in', 12: 'turn', 13: 'provides', 14: 'variable electric current', 15: 'to', 16: 'the magnetic off-loader', 17: 'which', 18: 'then', 19: 'provides', 20: 'a magnetic lifting force', 21: 'to', 22: 'the rotor', 23: 'on', 24: 'the shaft', 25: 'to', 26: 'minimize', 27: 'bearing load', 28: '.'}), (([7, 13, 22], 0.0267767533659935), {0: 'response', 1: 'to', 2: 'changes', 3: 'in', 4: 'the distance', 5: 'the sensor', 6: 'sends', 7: 'an electrical signal', 8: 'to', 9: 'a controller', 10: 'which', 11: 'in', 12: 'turn', 13: 'provides', 14: 'variable electric current', 15: 'to', 16: 'the magnetic off-loader', 17: 'which', 18: 'then', 19: 'provides', 20: 'a magnetic lifting force', 21: 'to', 22: 'the rotor', 23: 'on', 24: 'the shaft', 25: 'to', 26: 'minimize', 27: 'bearing load', 28: '.'}), (([7, 19, 24], 0.027500047348439693), {0: 'response', 1: 'to', 2: 'changes', 3: 'in', 4: 'the distance', 5: 'the sensor', 6: 'sends', 7: 'an electrical signal', 8: 'to', 9: 'a controller', 10: 'which', 11: 'in', 12: 'turn', 13: 'provides', 14: 'variable electric current', 15: 'to', 16: 'the magnetic off-loader', 17: 'which', 18: 'then', 19: 'provides', 20: 'a magnetic lifting force', 21: 'to', 22: 'the rotor', 23: 'on', 24: 'the shaft', 25: 'to', 26: 'minimize', 27: 'bearing load', 28: '.'}), (([7, 26, 27], 0.055355858989059925), {0: 'response', 1: 'to', 2: 'changes', 3: 'in', 4: 'the distance', 5: 'the sensor', 6: 'sends', 7: 'an electrical signal', 8: 'to', 9: 'a controller', 10: 'which', 11: 'in', 12: 'turn', 13: 'provides', 14: 'variable electric current', 15: 'to', 16: 'the magnetic off-loader', 17: 'which', 18: 'then', 19: 'provides', 20: 'a magnetic lifting force', 21: 'to', 22: 'the rotor', 23: 'on', 24: 'the shaft', 25: 'to', 26: 'minimize', 27: 'bearing load', 28: '.'}), (([9, 13, 14], 0.06677882373332977), {0: 'response', 1: 'to', 2: 'changes', 3: 'in', 4: 'the distance', 5: 'the sensor', 6: 'sends', 7: 'an electrical signal', 8: 'to', 9: 'a controller', 10: 'which', 11: 'in', 12: 'turn', 13: 'provides', 14: 'variable electric current', 15: 'to', 16: 'the magnetic off-loader', 17: 'which', 18: 'then', 19: 'provides', 20: 'a magnetic lifting force', 21: 'to', 22: 'the rotor', 23: 'on', 24: 'the shaft', 25: 'to', 26: 'minimize', 27: 'bearing load', 28: '.'}), (([9, 13, 16], 0.04022593703120947), {0: 'response', 1: 'to', 2: 'changes', 3: 'in', 4: 'the distance', 5: 'the sensor', 6: 'sends', 7: 'an electrical signal', 8: 'to', 9: 'a controller', 10: 'which', 11: 'in', 12: 'turn', 13: 'provides', 14: 'variable electric current', 15: 'to', 16: 'the magnetic off-loader', 17: 'which', 18: 'then', 19: 'provides', 20: 'a magnetic lifting force', 21: 'to', 22: 'the rotor', 23: 'on', 24: 'the shaft', 25: 'to', 26: 'minimize', 27: 'bearing load', 28: '.'}), (([9, 19, 20], 0.041372363455593586), {0: 'response', 1: 'to', 2: 'changes', 3: 'in', 4: 'the distance', 5: 'the sensor', 6: 'sends', 7: 'an electrical signal', 8: 'to', 9: 'a controller', 10: 'which', 11: 'in', 12: 'turn', 13: 'provides', 14: 'variable electric current', 15: 'to', 16: 'the magnetic off-loader', 17: 'which', 18: 'then', 19: 'provides', 20: 'a magnetic lifting force', 21: 'to', 22: 'the rotor', 23: 'on', 24: 'the shaft', 25: 'to', 26: 'minimize', 27: 'bearing load', 28: '.'}), (([9, 13, 22], 0.03553422726690769), {0: 'response', 1: 'to', 2: 'changes', 3: 'in', 4: 'the distance', 5: 'the sensor', 6: 'sends', 7: 'an electrical signal', 8: 'to', 9: 'a controller', 10: 'which', 11: 'in', 12: 'turn', 13: 'provides', 14: 'variable electric current', 15: 'to', 16: 'the magnetic off-loader', 17: 'which', 18: 'then', 19: 'provides', 20: 'a magnetic lifting force', 21: 'to', 22: 'the rotor', 23: 'on', 24: 'the shaft', 25: 'to', 26: 'minimize', 27: 'bearing load', 28: '.'}), (([9, 13, 24], 0.03466932848095894), {0: 'response', 1: 'to', 2: 'changes', 3: 'in', 4: 'the distance', 5: 'the sensor', 6: 'sends', 7: 'an electrical signal', 8: 'to', 9: 'a controller', 10: 'which', 11: 'in', 12: 'turn', 13: 'provides', 14: 'variable electric current', 15: 'to', 16: 'the magnetic off-loader', 17: 'which', 18: 'then', 19: 'provides', 20: 'a magnetic lifting force', 21: 'to', 22: 'the rotor', 23: 'on', 24: 'the shaft', 25: 'to', 26: 'minimize', 27: 'bearing load', 28: '.'}), (([9, 26, 27], 0.05572216026484966), {0: 'response', 1: 'to', 2: 'changes', 3: 'in', 4: 'the distance', 5: 'the sensor', 6: 'sends', 7: 'an electrical signal', 8: 'to', 9: 'a controller', 10: 'which', 11: 'in', 12: 'turn', 13: 'provides', 14: 'variable electric current', 15: 'to', 16: 'the magnetic off-loader', 17: 'which', 18: 'then', 19: 'provides', 20: 'a magnetic lifting force', 21: 'to', 22: 'the rotor', 23: 'on', 24: 'the shaft', 25: 'to', 26: 'minimize', 27: 'bearing load', 28: '.'}), (([12, 13, 14], 0.07495643198490143), {0: 'response', 1: 'to', 2: 'changes', 3: 'in', 4: 'the distance', 5: 'the sensor', 6: 'sends', 7: 'an electrical signal', 8: 'to', 9: 'a controller', 10: 'which', 11: 'in', 12: 'turn', 13: 'provides', 14: 'variable electric current', 15: 'to', 16: 'the magnetic off-loader', 17: 'which', 18: 'then', 19: 'provides', 20: 'a magnetic lifting force', 21: 'to', 22: 'the rotor', 23: 'on', 24: 'the shaft', 25: 'to', 26: 'minimize', 27: 'bearing load', 28: '.'}), (([12, 13, 16], 0.048403545282781124), {0: 'response', 1: 'to', 2: 'changes', 3: 'in', 4: 'the distance', 5: 'the sensor', 6: 'sends', 7: 'an electrical signal', 8: 'to', 9: 'a controller', 10: 'which', 11: 'in', 12: 'turn', 13: 'provides', 14: 'variable electric current', 15: 'to', 16: 'the magnetic off-loader', 17: 'which', 18: 'then', 19: 'provides', 20: 'a magnetic lifting force', 21: 'to', 22: 'the rotor', 23: 'on', 24: 'the shaft', 25: 'to', 26: 'minimize', 27: 'bearing load', 28: '.'}), (([12, 13, 20], 0.04595712758600712), {0: 'response', 1: 'to', 2: 'changes', 3: 'in', 4: 'the distance', 5: 'the sensor', 6: 'sends', 7: 'an electrical signal', 8: 'to', 9: 'a controller', 10: 'which', 11: 'in', 12: 'turn', 13: 'provides', 14: 'variable electric current', 15: 'to', 16: 'the magnetic off-loader', 17: 'which', 18: 'then', 19: 'provides', 20: 'a magnetic lifting force', 21: 'to', 22: 'the rotor', 23: 'on', 24: 'the shaft', 25: 'to', 26: 'minimize', 27: 'bearing load', 28: '.'}), (([12, 13, 22], 0.04371183551847935), {0: 'response', 1: 'to', 2: 'changes', 3: 'in', 4: 'the distance', 5: 'the sensor', 6: 'sends', 7: 'an electrical signal', 8: 'to', 9: 'a controller', 10: 'which', 11: 'in', 12: 'turn', 13: 'provides', 14: 'variable electric current', 15: 'to', 16: 'the magnetic off-loader', 17: 'which', 18: 'then', 19: 'provides', 20: 'a magnetic lifting force', 21: 'to', 22: 'the rotor', 23: 'on', 24: 'the shaft', 25: 'to', 26: 'minimize', 27: 'bearing load', 28: '.'}), (([12, 13, 24], 0.042846936732530594), {0: 'response', 1: 'to', 2: 'changes', 3: 'in', 4: 'the distance', 5: 'the sensor', 6: 'sends', 7: 'an electrical signal', 8: 'to', 9: 'a controller', 10: 'which', 11: 'in', 12: 'turn', 13: 'provides', 14: 'variable electric current', 15: 'to', 16: 'the magnetic off-loader', 17: 'which', 18: 'then', 19: 'provides', 20: 'a magnetic lifting force', 21: 'to', 22: 'the rotor', 23: 'on', 24: 'the shaft', 25: 'to', 26: 'minimize', 27: 'bearing load', 28: '.'}), (([12, 26, 27], 0.05772625096142292), {0: 'response', 1: 'to', 2: 'changes', 3: 'in', 4: 'the distance', 5: 'the sensor', 6: 'sends', 7: 'an electrical signal', 8: 'to', 9: 'a controller', 10: 'which', 11: 'in', 12: 'turn', 13: 'provides', 14: 'variable electric current', 15: 'to', 16: 'the magnetic off-loader', 17: 'which', 18: 'then', 19: 'provides', 20: 'a magnetic lifting force', 21: 'to', 22: 'the rotor', 23: 'on', 24: 'the shaft', 25: 'to', 26: 'minimize', 27: 'bearing load', 28: '.'}), (([14, 19, 20], 0.04250659979879856), {0: 'response', 1: 'to', 2: 'changes', 3: 'in', 4: 'the distance', 5: 'the sensor', 6: 'sends', 7: 'an electrical signal', 8: 'to', 9: 'a controller', 10: 'which', 11: 'in', 12: 'turn', 13: 'provides', 14: 'variable electric current', 15: 'to', 16: 'the magnetic off-loader', 17: 'which', 18: 'then', 19: 'provides', 20: 'a magnetic lifting force', 21: 'to', 22: 'the rotor', 23: 'on', 24: 'the shaft', 25: 'to', 26: 'minimize', 27: 'bearing load', 28: '.'}), (([14, 19, 22], 0.030874814838171005), {0: 'response', 1: 'to', 2: 'changes', 3: 'in', 4: 'the distance', 5: 'the sensor', 6: 'sends', 7: 'an electrical signal', 8: 'to', 9: 'a controller', 10: 'which', 11: 'in', 12: 'turn', 13: 'provides', 14: 'variable electric current', 15: 'to', 16: 'the magnetic off-loader', 17: 'which', 18: 'then', 19: 'provides', 20: 'a magnetic lifting force', 21: 'to', 22: 'the rotor', 23: 'on', 24: 'the shaft', 25: 'to', 26: 'minimize', 27: 'bearing load', 28: '.'}), (([14, 19, 24], 0.031701454892754555), {0: 'response', 1: 'to', 2: 'changes', 3: 'in', 4: 'the distance', 5: 'the sensor', 6: 'sends', 7: 'an electrical signal', 8: 'to', 9: 'a controller', 10: 'which', 11: 'in', 12: 'turn', 13: 'provides', 14: 'variable electric current', 15: 'to', 16: 'the magnetic off-loader', 17: 'which', 18: 'then', 19: 'provides', 20: 'a magnetic lifting force', 21: 'to', 22: 'the rotor', 23: 'on', 24: 'the shaft', 25: 'to', 26: 'minimize', 27: 'bearing load', 28: '.'}), (([14, 26, 27], 0.06257753819227219), {0: 'response', 1: 'to', 2: 'changes', 3: 'in', 4: 'the distance', 5: 'the sensor', 6: 'sends', 7: 'an electrical signal', 8: 'to', 9: 'a controller', 10: 'which', 11: 'in', 12: 'turn', 13: 'provides', 14: 'variable electric current', 15: 'to', 16: 'the magnetic off-loader', 17: 'which', 18: 'then', 19: 'provides', 20: 'a magnetic lifting force', 21: 'to', 22: 'the rotor', 23: 'on', 24: 'the shaft', 25: 'to', 26: 'minimize', 27: 'bearing load', 28: '.'}), (([16, 19, 20], 0.0469520203769207), {0: 'response', 1: 'to', 2: 'changes', 3: 'in', 4: 'the distance', 5: 'the sensor', 6: 'sends', 7: 'an electrical signal', 8: 'to', 9: 'a controller', 10: 'which', 11: 'in', 12: 'turn', 13: 'provides', 14: 'variable electric current', 15: 'to', 16: 'the magnetic off-loader', 17: 'which', 18: 'then', 19: 'provides', 20: 'a magnetic lifting force', 21: 'to', 22: 'the rotor', 23: 'on', 24: 'the shaft', 25: 'to', 26: 'minimize', 27: 'bearing load', 28: '.'}), (([16, 19, 22], 0.035320235416293144), {0: 'response', 1: 'to', 2: 'changes', 3: 'in', 4: 'the distance', 5: 'the sensor', 6: 'sends', 7: 'an electrical signal', 8: 'to', 9: 'a controller', 10: 'which', 11: 'in', 12: 'turn', 13: 'provides', 14: 'variable electric current', 15: 'to', 16: 'the magnetic off-loader', 17: 'which', 18: 'then', 19: 'provides', 20: 'a magnetic lifting force', 21: 'to', 22: 'the rotor', 23: 'on', 24: 'the shaft', 25: 'to', 26: 'minimize', 27: 'bearing load', 28: '.'}), (([16, 19, 24], 0.036146875470876694), {0: 'response', 1: 'to', 2: 'changes', 3: 'in', 4: 'the distance', 5: 'the sensor', 6: 'sends', 7: 'an electrical signal', 8: 'to', 9: 'a controller', 10: 'which', 11: 'in', 12: 'turn', 13: 'provides', 14: 'variable electric current', 15: 'to', 16: 'the magnetic off-loader', 17: 'which', 18: 'then', 19: 'provides', 20: 'a magnetic lifting force', 21: 'to', 22: 'the rotor', 23: 'on', 24: 'the shaft', 25: 'to', 26: 'minimize', 27: 'bearing load', 28: '.'}), (([16, 26, 27], 0.05617948528379202), {0: 'response', 1: 'to', 2: 'changes', 3: 'in', 4: 'the distance', 5: 'the sensor', 6: 'sends', 7: 'an electrical signal', 8: 'to', 9: 'a controller', 10: 'which', 11: 'in', 12: 'turn', 13: 'provides', 14: 'variable electric current', 15: 'to', 16: 'the magnetic off-loader', 17: 'which', 18: 'then', 19: 'provides', 20: 'a magnetic lifting force', 21: 'to', 22: 'the rotor', 23: 'on', 24: 'the shaft', 25: 'to', 26: 'minimize', 27: 'bearing load', 28: '.'}), (([20, 26, 27], 0.06736447848379612), {0: 'response', 1: 'to', 2: 'changes', 3: 'in', 4: 'the distance', 5: 'the sensor', 6: 'sends', 7: 'an electrical signal', 8: 'to', 9: 'a controller', 10: 'which', 11: 'in', 12: 'turn', 13: 'provides', 14: 'variable electric current', 15: 'to', 16: 'the magnetic off-loader', 17: 'which', 18: 'then', 19: 'provides', 20: 'a magnetic lifting force', 21: 'to', 22: 'the rotor', 23: 'on', 24: 'the shaft', 25: 'to', 26: 'minimize', 27: 'bearing load', 28: '.'}), (([22, 26, 27], 0.06666450574994087), {0: 'response', 1: 'to', 2: 'changes', 3: 'in', 4: 'the distance', 5: 'the sensor', 6: 'sends', 7: 'an electrical signal', 8: 'to', 9: 'a controller', 10: 'which', 11: 'in', 12: 'turn', 13: 'provides', 14: 'variable electric current', 15: 'to', 16: 'the magnetic off-loader', 17: 'which', 18: 'then', 19: 'provides', 20: 'a magnetic lifting force', 21: 'to', 22: 'the rotor', 23: 'on', 24: 'the shaft', 25: 'to', 26: 'minimize', 27: 'bearing load', 28: '.'}), (([24, 26, 27], 0.08730490505695343), {0: 'response', 1: 'to', 2: 'changes', 3: 'in', 4: 'the distance', 5: 'the sensor', 6: 'sends', 7: 'an electrical signal', 8: 'to', 9: 'a controller', 10: 'which', 11: 'in', 12: 'turn', 13: 'provides', 14: 'variable electric current', 15: 'to', 16: 'the magnetic off-loader', 17: 'which', 18: 'then', 19: 'provides', 20: 'a magnetic lifting force', 21: 'to', 22: 'the rotor', 23: 'on', 24: 'the shaft', 25: 'to', 26: 'minimize', 27: 'bearing load', 28: '.'})]

# %%
def filter_relation_only(all_relation_pairs):
    all_triplets_c = []
    triplets = []
    cs = []
    for i in all_relation_pairs:
        triplet_c, id2token = i
        all_triplets_c.append(triplet_c)

    for triplet, c in all_triplets_c:
        triplets.append(triplet)
        cs.append(c)


    relation_ls = list()
    for triple in triplets:
        if triple[1] not in relation_ls:
            relation_ls.append(triple[1])
    dic = dict()
    for r in relation_ls:
        dic[r] = []

    for triplet, c in all_triplets_c:
        dic[triplet[1]].append((triplet[0], triplet[2], c))

    value_filtered = []
    for key, value in dic.items():
        value_sorted= sorted(value, key=lambda x: x[2],reverse=True)
        # print ('old')
        # print (value_sorted)
        h_golden = value_sorted[0][0]
        count = 0
        for value_ in value_sorted:

            if value_[0] == h_golden:
                count = count+1
                value_filtered.append((([value_[0],key,value_[1]],value_[2]),id2token))
            if count ==2:
                break



    return (value_filtered)

def filter_tail_only(all_relation_pairs):
    all_triplets_c = []
    triplets = []
    cs = []
    for i in all_relation_pairs:
        triplet_c, id2token = i
        all_triplets_c.append(triplet_c)

    for triplet, c in all_triplets_c:
        triplets.append(triplet)
        cs.append(c)


    tail_ls = list()
    for triple in triplets:
        if triple[2] not in tail_ls:
            tail_ls.append(triple[2])
    dic = dict()
    for tail in tail_ls:
        dic[tail] = []

    for triplet, c in all_triplets_c:
        dic[triplet[2]].append((triplet[0], triplet[1], c))

    value_filtered = []
    for key, value in dic.items():
        value_sorted= sorted(value, key=lambda x: x[2],reverse=True)
        # print ('old')
        # print (value_sorted)
        h_golden = value_sorted[0][0]
        count = 0
        for value_ in value_sorted:

            if value_[0] == h_golden:
                count = count+1
                value_filtered.append((([value_[0],key,value_[1]],value_[2]),id2token))
            if count ==2:
                break



    return (value_filtered)

# %%
dic = filter_relation_only(test_all_re_1)
# Out:
# {5: [], 4: [], 10: [], 16: [], 14: [], 12: []}
# ...

# %%
print(dic)
new_dic= dict()
for key,value in dic.items():

    values = sorted(value, key=lambda x:[1])
    print ('old')
    print (values)
#     h_golden = values[0][0]

#     for value in values_new:
#         if value[0] != h_golden:
#             values_new.remove(value)
#     print ('new')
#     print (values_new)

#     new_dic[item]= values_new
    
print (new_dic)
# Out:
# {5: [(0, 6, 0.14362630806863308)], 4: [(0, 8, 0.05523030832409859), (0, 13, 0.053493063896894455), (0, 19, 0.04878399521112442), (0, 21, 0.044417692348361015), (0, 23, 0.045050433836877346), (0, 25, 0.04735935013741255), (0, 27, 0.04657481238245964)], 10: [(0, 11, 0.057122115045785904), (6, 11, 0.060095289722085), (6, 13, 0.045095156878232956), (6, 21, 0.03723613265901804), (6, 23, 0.04032389726489782), (6, 25, 0.0383484847843647), (6, 27, 0.03957377281039953), (8, 11, 0.0629549901932478), (8, 13, 0.04795485734939575), (8, 19, 0.04293336346745491), (8, 21, 0.040095833130180836), (8, 23, 0.04318359773606062), (8, 25, 0.041208185255527496), (8, 27, 0.04243347328156233)], 16: [(0, 17, 0.05699444189667702), (6, 17, 0.05438375286757946), (8, 17, 0.054662518203258514), (11, 17, 0.05551338754594326), (13, 17, 0.06570327468216419)], 14: [(6, 19, 0.04191224277019501), (11, 19, 0.04442876577377319), (11, 25, 0.03827801439911127), (11, 27, 0.04197405278682709), (13, 19, 0.0553881898522377), (13
# ...
